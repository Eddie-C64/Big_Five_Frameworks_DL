# %% [markdown]
# # Simple Feed Forward Network in Keras
# In this modeule we create a simple feed forward network with Keras, the easiest of the deep learning frameworks. We will first start by loading the Pima-Indian Diabetes dataset.

# %%
# Dependecies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Data
pima_df = pd.read_csv('diabetes.csv')

print(pima_df.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
print(pima_df.groupby(['Outcome']).size())
print('\nTotal number of data rows: ', print(pima_df.shape[0]))
# Out:
# Outcome
# 0    500
# 1    268
# dtype: int64
# 768
#
# Total number of data rows:  None

# %%
# Split Data into X and y
x_input = pima_df.drop(['Outcome'], axis=1).values
y_ouput = pima_df['Outcome'].values

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_input, y_ouput, test_size=0.20, random_state=42)

# %%
print(x_train.shape)
print(y_train.shape)
print('\n',x_test.shape)
print(y_test.shape)
# Out:
# (614, 8)
# (614,)
#
#  (154, 8)
# (154,)

# %%
from keras.layers import Dense
from keras.models import Sequential

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Fit the model
model.fit(x_train, y_train, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 614/614 [==============================] - 0s - loss: 5.5627 - acc: 0.6531
# Epoch 2/150
# 614/614 [==============================] - 0s - loss: 5.4625 - acc: 0.6547
# Epoch 3/150
# 614/614 [==============================] - 0s - loss: 5.3390 - acc: 0.6433
# Epoch 4/150
# 614/614 [==============================] - 0s - loss: 2.9226 - acc: 0.5717
# Epoch 5/150
# 614/614 [==============================] - 0s - loss: 1.1497 - acc: 0.5293
# Epoch 6/150
# 614/614 [==============================] - 0s - loss: 0.8743 - acc: 0.5814
# Epoch 7/150
# 614/614 [==============================] - 0s - loss: 0.8193 - acc: 0.5700
# Epoch 8/150
# 614/614 [==============================] - 0s - loss: 0.7545 - acc: 0.5733
# Epoch 9/150
# 614/614 [==============================] - 0s - loss: 0.7362 - acc: 0.6221
# Epoch 10/150
# 614/614 [==============================] - 0s - loss: 0.7056 - acc: 0.6303
# Epoch 11/150
# ...

# %%
score = model.evaluate(x_test, y_test)
# Out:
#  32/154 [=====>........................] - ETA: 0s

# %%
print(score)
# Out:
# [0.60690690751199594, 0.70779221011446669]
